# %% [markdown]
# > [!Warning]
# > **This project is still in an early phase of development.**
# >
# > The [python API](../api.html) is not yet stable, and some aspects of the schema for the [blueprint](../terminology.html#term-blueprint) will likely evolve.
# > Therefore whilst you are welcome to try out using the package, we cannot yet guarantee backwards compatibility.
# We expect to reach a more stable version in Q1 2025.
# >
# > To see which systems C-Star has been tested on so far, see [Supported Systems](../machines.html).

# %% [markdown]
# # Restarting & continuing a `ROMSSimulation`
#
# ## Contents
# 1. [Introduction](#1.-Introduction)
# 2. [Restoring and restarting the Simulation](#2.-Restoring-and-restarting-the-Simulation)
#    - [Restoring](#Restoring)
#    - [Restarting](#Restarting)
#    - [Modifying the time step](#Modifying-the-time-step)
# 3. [Running the restarted Simulation](#3.-Running-the-restarted-Case)
# 4. [Some basic analysis of the output](#4.-Some-basic-analysis-of-the-output)

# %% [markdown]
# ## 1. Introduction
#
# [(return to top)](#Contents)
#
# In this guide we will:
#
# - Take the Simulation we ran for two days (2012-01-01 to 2012-01-03) on the [previous page](../tutorials/2_importing_and_running_a_simulation_from_a_blueprint.html) and create a new Simulation that picks up where it ends (`ROMSSimulation.restart()`)
# - Run this second case with a larger time step for the remainder of the month of January 2012
# - Produce a basic plot of the output
#
# On the [previous page](../tutorials/2_importing_and_running_a_simulation_from_a_blueprint.html), we began this run from a set of prescribed initial conditions and ran it for two days with a short time step of 1 minute. We should now be able to safely restart the model with a slightly larger time step.
# To do this, we can use the `ROMSSimulation.restart()` method, which returns a new `ROMSSimulation` whose start date corresponds to the end date of the Simulation we began with, and whose initial conditions are replaced with a restart file from our previous run. The directory of the restart will be a subdirectory of the original simulation directory.
#
# ## 2. Restoring and restarting the Simulation
#
# [(return to top)](#Contents)
#
# ### Restoring
# First, we restore the previously created simulation using `ROMSSimulation.restore()`. The state of the `ROMSSimulation` is regularly saved to a file in the `directory` so it can be restored exactly in a new python session.

# %%
from cstar.roms import ROMSSimulation
from cstar.execution.handler import ExecutionStatus

original_simulation = ROMSSimulation.restore(
    directory="../../examples/outputs/roms_marbl_example"
)

# %% [markdown]
# ### Restarting
# Now, we can create a new `ROMSSimulation` that picks up where this `ROMSSimulation` ended using `ROMSSimulation.restart()`. Some points:
# - We supply a `new_end_date` (the new *start* date is simply the previous end date)
# - The `directory` of the new, restarted `ROMSSimulation` is automatically generated as a subdirectory of the previous `directory`
# - The initial conditions of the new simulation are automatically replaced with a restart file generated by ROMS during the previous run

# %%
restarted_simulation = original_simulation.restart(new_end_date="2012-01-31 12:00:00")

# %% [markdown]
# Taking a look at the simulation, we can see that the initial conditions have been changed:

# %%
restarted_simulation.initial_conditions
# Out:
# ROMSInitialConditions(
# location = '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/output/ROMS_MARBL_rst.20120103120000.nc',
# file_hash = None,
# start_date = datetime.datetime(2012, 1, 3, 12, 0),
# )

# %% [markdown]
# ### Modifying the time step

# %% [markdown]
# If we want to increase the time step for our second run, we will have to manually change the `time_step` entry under `ROMSSimulation.discretization`:

# %%
restarted_simulation
# Out:
# ROMSSimulation(
# name = roms_marbl_example_cstar_simulation,
# directory = /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000,
# start_date = 2012-01-03 12:00:00,
# end_date = 2012-01-31 12:00:00,
# valid_start_date = 2012-01-01 12:00:00,
# valid_end_date = 2012-01-31 12:00:00,
# discretization = ROMSDiscretization(time_step = 60, n_procs_x = 3, n_procs_y = 3),
# codebase = <ROMSExternalCodeBase instance>,
# runtime_code = <AdditionalCode instance>,
# compile_time_code = <AdditionalCode instance>
# model_grid = <ROMSModelGrid instance>,
# initial_conditions = <ROMSInitialConditions instance>,
# tidal_forcing = <ROMSTidalForcing instance>,
# river_forcing = <ROMSRiverForcing instance>,
# surface_forcing = <list of 2 ROMSSurfaceForcing instances>,
# boundary_forcing = <list of 2 ROMSBoundaryForcing instances>,
# )

# %%
restarted_simulation.discretization.time_step = 360

# %% [markdown]
# We can now take a look at our `ROMSSimulation` and see everything is as expected:

# %%
restarted_simulation
# Out:
# ROMSSimulation(
# name = roms_marbl_example_cstar_simulation,
# directory = /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000,
# start_date = 2012-01-03 12:00:00,
# end_date = 2012-01-31 12:00:00,
# valid_start_date = 2012-01-01 12:00:00,
# valid_end_date = 2012-01-31 12:00:00,
# discretization = ROMSDiscretization(time_step = 360, n_procs_x = 3, n_procs_y = 3),
# codebase = <ROMSExternalCodeBase instance>,
# runtime_code = <AdditionalCode instance>,
# compile_time_code = <AdditionalCode instance>
# model_grid = <ROMSModelGrid instance>,
# initial_conditions = <ROMSInitialConditions instance>,
# tidal_forcing = <ROMSTidalForcing instance>,
# river_forcing = <ROMSRiverForcing instance>,
# surface_forcing = <list of 2 ROMSSurfaceForcing instances>,
# boundary_forcing = <list of 2 ROMSBoundaryForcing instances>,
# )

# %% [markdown]
# ## 3. Running the restarted `Simulation`
#
# [(return to top)](#Contents)
#
# Now we run through the other steps as normal:

# %%
restarted_simulation.setup()
restarted_simulation.build()
restarted_simulation.pre_run()
# Out:
# 2025-04-16 14:53:58,923 | INFO | cstar.roms.simulation.ROMSSimulation::setup:1094: Configuring ROMSSimulation
# --------------------------
# 2025-04-16 14:53:58,923 | INFO | cstar.roms.simulation.ROMSSimulation::setup:1095: Setting up ROMSExternalCodeBase...
# Retrieving URL for remote in repository `/Users/chris/code/cstar/cstar/externals/ucla-roms`.
# Retrieved URL for remote in repository `/Users/chris/code/cstar/cstar/externals/ucla-roms`.
# Retrieving commit hash for repository `/Users/chris/code/cstar/cstar/externals/ucla-roms`.
# Retrieved commit hash for repository `/Users/chris/code/cstar/cstar/externals/ucla-roms`.
# Retrieving remote refs for repository `https://github.com/CESR-lab/ucla-roms.git`.
# 2025-04-16 14:53:59,224 | INFO | cstar.roms.external_codebase.ROMSExternalCodeBase::handle_config_status:232: ROMSExternalCodeBase correctly configured. Nothing to be done
# 2025-04-16 14:53:59,224 | INFO | cstar.roms.simulation.ROMSSimulation::setup:1099: Setting up MARBLExternalCodeBase...
# Retrieved remote refs for repository `https://github.com/CESR-lab/ucla-roms.git`.
# Retrieving URL for remote in repository `/Users/chris/code/cstar/cstar/externals/MARBL`.
# Retrieved URL for remote in repository `/Users/chris/code/cstar/cstar/externals/MARBL`.
# Retrieving commit hash for repository `/Users/chris/code/cstar/cstar/externals/MARBL`.
# Retrieved commit hash for repository `/Users/chris/code/cstar/cstar/externals/MARBL`.
# Retrieving remote refs for repository `https://github.com/marbl-ecosys/MARBL.git`.
# 2025-04-16 14:53:59,522 | INFO | cstar.marbl.external_codebase.MARBLExternalCodeBase::handle_config_status:232: MARBLExternalCodeBase correctly configured. Nothing to be done
# 2025-04-16 14:53:59,523 | INFO | cstar.roms.simulation.ROMSSimulation::setup:1103:
# Fetching compile-time code code...
# ----------------------------------
# Retrieved remote refs for repository `https://github.com/marbl-ecosys/MARBL.git`.
# Cloning `https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example.git`
# 2025-04-16 14:54:00,456 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying bgc.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,458 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying bulk_frc.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,458 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying cppdefs.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,459 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying diagnostics.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,459 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying ocean_vars.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,460 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying param.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,460 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying tracers.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,461 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying river_frc.opt to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,462 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying Makefile to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,462 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying Make.depend to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:00,466 | INFO | cstar.roms.simulation.ROMSSimulation::setup:1111:
# Fetching runtime code...
# ----------------------
# Cloned https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example.git to /var/folders/pj/bk3042bs0tldhwq8htgfnm640000gn/T/tmp10mjvc1l
# Checking out `https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example.git` @ `main`
# Checked out main in git repository /var/folders/pj/bk3042bs0tldhwq8htgfnm640000gn/T/tmp10mjvc1l
# Cloning `https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example.git`
# 2025-04-16 14:54:01,196 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying roms.in_TEMPLATE to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/runtime_code
# 2025-04-16 14:54:01,197 | INFO | cstar.base.additional_code.AdditionalCode::get:222: Copying template file /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/runtime_code/roms.in_TEMPLATE to editable version /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/runtime_code/roms.in
# 2025-04-16 14:54:01,197 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying marbl_in to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/runtime_code
# 2025-04-16 14:54:01,198 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying marbl_tracer_output_list to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/runtime_code
# 2025-04-16 14:54:01,199 | INFO | cstar.base.additional_code.AdditionalCode::get:209: Copying marbl_diagnostic_output_list to /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/runtime_code
# 2025-04-16 14:54:01,203 | INFO | cstar.roms.simulation.ROMSSimulation::setup:1116:
# Fetching input datasets...
# --------------------------
# Downloading file 'roms_grd.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_grd.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Cloned https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example.git to /var/folders/pj/bk3042bs0tldhwq8htgfnm640000gn/T/tmphmigmmte
# Checking out `https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example.git` @ `main`
# Checked out main in git repository /var/folders/pj/bk3042bs0tldhwq8htgfnm640000gn/T/tmphmigmmte
# Downloading file 'roms_tides.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_tides.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Downloading file 'roms_riv_frc.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_riv_frc.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Downloading file 'roms_bry.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_bry.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Downloading file 'roms_bry_bgc.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_bry_bgc.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Downloading file 'roms_frc.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_frc.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Downloading file 'roms_frc_bgc.nc' from 'https://github.com/CWorthy-ocean/cstar_blueprint_roms_marbl_example/raw/netcdf_inputs/input_datasets_netcdf/roms_frc_bgc.nc' to '/Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets'.
# Compiling UCLA-ROMS configuration...
# 2025-04-16 14:54:13,532 | INFO | cstar.roms.input_dataset.ROMSModelGrid::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_grd.nc into (3,3)
# 2025-04-16 14:54:13,666 | INFO | cstar.roms.input_dataset.ROMSInitialConditions::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/ROMS_MARBL_rst.20120103120000.nc into (3,3)
# UCLA-ROMS compiled at /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/compile_time_code
# 2025-04-16 14:54:14,146 | INFO | cstar.roms.input_dataset.ROMSTidalForcing::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_tides.nc into (3,3)
# 2025-04-16 14:54:14,194 | INFO | cstar.roms.input_dataset.ROMSRiverForcing::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_riv_frc.nc into (3,3)
# /opt/anaconda3/envs/cstar/lib/python3.13/site-packages/roms_tools/tiling/partition.py:322: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(filepath.with_suffix(".nc"))
# 2025-04-16 14:54:14,266 | INFO | cstar.roms.input_dataset.ROMSBoundaryForcing::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_bry.nc into (3,3)
# /opt/anaconda3/envs/cstar/lib/python3.13/site-packages/roms_tools/tiling/partition.py:322: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(filepath.with_suffix(".nc"))
# 2025-04-16 14:54:14,376 | INFO | cstar.roms.input_dataset.ROMSBoundaryForcing::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_bry_bgc.nc into (3,3)
# /opt/anaconda3/envs/cstar/lib/python3.13/site-packages/roms_tools/tiling/partition.py:322: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(filepath.with_suffix(".nc"))
# 2025-04-16 14:54:14,851 | INFO | cstar.roms.input_dataset.ROMSSurfaceForcing::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_frc.nc into (3,3)
# /opt/anaconda3/envs/cstar/lib/python3.13/site-packages/roms_tools/tiling/partition.py:322: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(filepath.with_suffix(".nc"))
# 2025-04-16 14:54:15,135 | INFO | cstar.roms.input_dataset.ROMSSurfaceForcing::partition:108: Partitioning /Users/chris/code/cstar/examples/outputs/roms_marbl_example/RESTART_20120103_120000/ROMS/input_datasets/roms_frc_bgc.nc into (3,3)
# /opt/anaconda3/envs/cstar/lib/python3.13/site-packages/roms_tools/tiling/partition.py:322: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(filepath.with_suffix(".nc"))

# %%
simulation_run = restarted_simulation.run()

# %% [markdown]
# As on the [previous page](../tutorials/2_importing_and_running_a_simulation_from_a_blueprint.html), we are running this Simulation [locally](../howto_guides/4_running_on_personal_computers.html). The call to `ROMSSimulation.run()` would be different on a supported [supercomputing system](../howto_guides/5_handling_jobs_on_hpc_systems.html).

# %%
simulation_run.status
# Out:
# <ExecutionStatus.RUNNING: 3>

# %% [markdown]
# Once again, we have to wait for the job to finish before proceeding...

# %%
simulation_run.status
# Out:
# <ExecutionStatus.RUNNING: 3>

# %%
# Use the handler to request status updates on the simulation
simulation_run.updates(0, confirm_indefinite=True)

if simulation_run.status != ExecutionStatus.RUNNING:
    print(simulation_run.status)

if simulation_run.status == ExecutionStatus.FAILED:
    print("An error occurred. See:", simulation_run.output_file)
# Out:
# 2025-04-16 14:54:26,551 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3551 4388.2958 3.94542273883-03 3.7506548787-03  0.029295542424  0.023933464207      5     30   11
#
# 2025-04-16 14:54:26,552 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,552 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3552 4388.3000 3.87445830508-03 3.6835770050-03  0.029378646122  0.024048527200      5     30   11
#
# 2025-04-16 14:54:26,552 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,553 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3553 4388.3041 3.80450678633-03 3.6173792911-03  0.029459234000  0.024161732010      5     30   11
#
# 2025-04-16 14:54:26,553 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,554 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3554 4388.3083 3.73551532838-03 3.5521067856-03  0.029565251265  0.024301701056      5     30   11
#
# 2025-04-16 14:54:26,554 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,555 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3555 4388.3125 3.66748264227-03 3.4877925710-03  0.029712906510  0.024483242472      5     30   11
#
# 2025-04-16 14:54:26,555 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,556 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3556 4388.3166 3.60049243558-03 3.4244603941-03  0.029807784779  0.024611128179      5     30   11
#
# 2025-04-16 14:54:26,556 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,557 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3557 4388.3208 3.53471112808-03 3.3621330764-03  0.029892131269  0.024735385694      5     30   11
#
# 2025-04-16 14:54:26,557 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,558 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3558 4388.3250 3.47005333317-03 3.3008276964-03  0.029972984664  0.024858688971      5     30   11
#
# 2025-04-16 14:54:26,558 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,558 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3559 4388.3291 3.40645446979-03 3.2405510822-03  0.030046921761  0.024967906032      5     30   11
#
# 2025-04-16 14:54:26,559 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,559 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3560 4388.3333 3.34399400736-03 3.1813086272-03  0.030117476789  0.025080770101      5     30   11
#
# 2025-04-16 14:54:26,559 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,560 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,560 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,665 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,666 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,666 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,666 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4388.38     rec = 130
#
# 2025-04-16 14:54:26,667 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,667 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3561 4388.3375 3.28268448056-03 3.1231010816-03  0.030187905891  0.025196716235      5     30   11
#
# 2025-04-16 14:54:26,667 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,668 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    
| INFO | cstar.execution.local_process.LocalProcess::updates:168:    3579 4388.4125 2.38895293164-03 2.2602316504-03  0.031504104661  0.027338842474      5     30   11
#
# 2025-04-16 14:54:26,885 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,885 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3580 4388.4166 2.35116869491-03 2.2224157446-03  0.031571245676  0.027455280854      5     30   11
#
# 2025-04-16 14:54:26,885 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,885 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,886 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,886 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,886 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,886 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,887 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4388.46     rec = 132
#
# 2025-04-16 14:54:26,887 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,887 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3581 4388.4208 2.31474715729-03 2.1856642586-03  0.031652359221  0.027593605955      5     30   11
#
# 2025-04-16 14:54:26,888 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,888 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3582 4388.4250 2.27961669196-03 2.1499563395-03  0.031703258985  0.027698927009      5     30   11
#
# 2025-04-16 14:54:26,888 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,889 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3583 4388.4291 2.24571018562-03 2.1152612269-03  0.031770031025  0.027821136207      5     30   11
#
# 2025-04-16 14:54:26,889 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,890 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3584 4388.4333 2.21301372776-03 2.0815641222-03  0.031851289081  0.027957944100      5     30   11
#
# 2025-04-16 14:54:26,890 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,996 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3585 4388.4375 2.18155539117-03 2.0488642761-03  0.031908605689  0.028070811073      5     30   11
#
# 2025-04-16 14:54:26,996 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,996 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3586 4388.4416 2.15132399496-03 2.0171658578-03  0.031982711296  0.028200061604      5     30   11
#
# 2025-04-16 14:54:26,997 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,997 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3587 4388.4458 2.12237094457-03 1.9864774989-03  0.032037839948  0.028310009355      5     30   11
#
# 2025-04-16 14:54:26,998 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,998 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3588 4388.4500 2.09464938271-03 1.9568106683-03  0.032105765049  0.028431885659      5     30   11
#
# 2025-04-16 14:54:26,999 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:26,999 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3589 4388.4541 2.06826448476-03 1.9281788442-03  0.032155596461  0.028534954040      5     30   11
#
# 2025-04-16 14:54:27,000 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,000 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3590 4388.4583 2.04318546082-03 1.9005947700-03  0.032230536311  0.028665290046      5     30   11
#
# 2025-04-16 14:54:27,000 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,000 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,001 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,001 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,001 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,002 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,002 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4388.50     rec = 133
#
# 2025-04-16 14:54:27,002 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,003 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3591 4388.4625 2.01949321742-03 1.8740698642-03  0.032305924095  0.028792522227      5     30   11
#
# 2025-04-16 14:54:27,003 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27
| INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatC
#
# 2025-04-16 14:54:27,233 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatP
#
# 2025-04-16 14:54:27,233 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatFe
#
# 2025-04-16 14:54:27,233 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatSi
#
# 2025-04-16 14:54:27,234 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazChl
#
# 2025-04-16 14:54:27,234 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazC
#
# 2025-04-16 14:54:27,235 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazP
#
# 2025-04-16 14:54:27,235 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazFe
#
# 2025-04-16 14:54:27,236 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        bgc :: wrote history, tdays =   4388.5000  step =   3599 rec =  13
#
# 2025-04-16 14:54:27,236 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        bgc diag :: wrote history, tdays =   4388.5000  step =   3600 rec =  13
#
# 2025-04-16 14:54:27,237 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: zeta_north       input time (days) =   4389.50     rec =   7
#
# 2025-04-16 14:54:27,237 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: zeta_west        input time (days) =   4389.50     rec =   7
#
# 2025-04-16 14:54:27,237 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: zeta_south       input time (days) =   4389.50     rec =   7
#
# 2025-04-16 14:54:27,342 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,343 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,343 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,344 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,344 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,344 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,345 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4388.54     rec = 134
#
# 2025-04-16 14:54:27,345 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,345 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3601 4388.5041 1.85799276790-03 1.6734251747-03  0.032966407536  0.030083755488      5     30   11
#
# 2025-04-16 14:54:27,345 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,345 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3602 4388.5083 1.84904152224-03 1.6595438328-03  0.033021050652  0.030208946070      5     30   11
#
# 2025-04-16 14:54:27,346 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,346 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3603 4388.5125 1.84088952337-03 1.6466540334-03  0.033080961058  0.030354199446      5     30   11
#
# 2025-04-16 14:54:27,346 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,346 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3604 4388.5166 1.83364458100-03 1.6346641153-03  0.033221353235  0.030212507189      5     30   10
#
# 2025-04-16 14:54:27,347 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,347 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3605 4388.5208 1.82705464641-03 1.6233687892-03  0.033369330261  0.030439624159      5     30   10
#
# 2025-04-16 14:54:27,347 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,348 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3606 4388.5250 1.82099401384-03 1.6126595224-03  0.033476156459  0.030620750663      5     30   10
#
# 2025-04-16 14:54:27,348 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,454 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3607 4388.5291 1.81533464422-03 1.6024382331-03  0.033590299591  0.030799520615      5     30   10
#
# 2025-04-16 14:54:27,454 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,454 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3608 4388.5333 1.81016008679-03 1.5926717860-03  0.033689722688  0.030963067089      5     30   10
#
# 2025-04-16 14:54:27,455 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,455 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3609 4388.5375 1.80527146390-03 1.5833566731-03  0.033788020503  0.031122930910      5     30   10
#
# 2025-04-16 14:54:27,456 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,456 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3610 4388.5416 1.80052838426-03 1.5743866165-03  0.033860945177  0.031255280080      5     30   10
#
# 2025-04-16 14:54:27,456 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,456 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,457 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,457 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,457 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,458 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,458 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4388.58     rec = 135
#
# 2025-04-16 14:54:27,459 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,459 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3611 4388.5458 1.79616644532-03 1.5657454534-03  0.033950321747  0.031397156361      5     30   10
#
# 2025-04-16 14:54:27,460 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,460 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3612 4388.5500 1.79212491033-03 1.5574710553-03  0.034036926151  0.031530292797      5     30   10
#
# 2025-04-16 14:54:27,461 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,461 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3613 4388.5541 1.78833020257-03 1.5495403985-03  0.034112411910  0.031646444537      5     30   10
#
# 2025-04-16 14:54:27,461 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,462 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3614 4388.5583 1.78491932447-03 1.5419864924-03  0.034181367362  0.031740492658      5     30   10
#
# 2025-04-16 14:54:27,465 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,465 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3615 4388.5625 1.78191971593-03 1.5347847541-03  0.034246905277  0.031821521218      5     30   10
#
# 2025-04-16 14:54:27,569 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,569 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3616 4388.5666 1.77924618867-03 1.5277827280-03  0.034314775210  0.031904556655      5     30   10
#
# 2025-04-16 14:54:27,569 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,570 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3617 4388.5708 1.77670776906-03 1.5208932452-03  0.034384371922  0.031988386825      5     30   10
#
# 2025-04-16 14:54:27,570 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,570 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3618 4388.5750 1.77447723723-03 1.5142835893-03  0.034463020073  0.032080327704      5     30   10
#
# 2025-04-16 14:54:27,571 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,571 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3619 4388.5791 1.77268555153-03 1.5081470937-03  0.034528764870  0.032157973674      5     30   10
#
# 2025-04-16 14:54:27,571 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,571 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3620 4388.5833 1.77133925885-03 1.5024442260-03  0.034586253982  0.032226485799      5     30   10
#
# 2025-04-16 14:54:27,572 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,572 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,573 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,573 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,573 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,574 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,574 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4388.62     rec = 136
#
# 2025-04-16 14:54:27,574 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,574 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3621 4388.5875 1.77043834374-03 1.4971858982-03  0.034640013432  0.032290706390      5     30   10
#
# 2025-04-16 14:54:27,575 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,575 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3622 4388.5916 1.76995998308-03 1.4924666022-03  0.034693846315  0.032354382244      5     30   10
#
# 2025-04-16 14:54:27,576 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27,576 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    3623 4388.5958 1.76986998946-03 1.4883198953-03  0.034747590714  0.032417062539      5     30   10
#
# 2025-04-16 14:54:27,682 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:54:27
| INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,837 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9590 4413.4583 1.68969363706-03 1.4435677337-03  0.030690301508  0.029609277362     28      4   10
#
# 2025-04-16 14:56:07,837 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: swrad            input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,837 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: lwrad            input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,838 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: uwnd             input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,838 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: vwnd             input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,839 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: Tair             input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,940 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: qair             input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,940 | INFO | cstar.execution.local_process.LocalProcess::updates:168:          set_frc :: rain             input time (days) =   4413.50     rec = 733
#
# 2025-04-16 14:56:07,941 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,941 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9591 4413.4625 1.68447158652-03 1.4393638234-03  0.031422558526  0.030370658758     28      4   10
#
# 2025-04-16 14:56:07,941 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,942 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9592 4413.4666 1.67889374892-03 1.4349146328-03  0.032158092600  0.031128303316     28      4   10
#
# 2025-04-16 14:56:07,943 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,943 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9593 4413.4708 1.67297526233-03 1.4302299102-03  0.032872877212  0.031933252086     28      4   10
#
# 2025-04-16 14:56:07,944 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,944 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9594 4413.4750 1.66677575754-03 1.4253351123-03  0.033378765596  0.032469570341     28      4   10
#
# 2025-04-16 14:56:07,944 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,945 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9595 4413.4791 1.66032042983-03 1.4202541076-03  0.033799536524  0.033035058221     28      4   10
#
# 2025-04-16 14:56:07,945 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,946 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9596 4413.4833 1.65363491029-03 1.4150097231-03  0.034302491054  0.033715501486     28      4   10
#
# 2025-04-16 14:56:07,946 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,947 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9597 4413.4875 1.64680293296-03 1.4096257246-03  0.034587306865  0.034111933734     28      4   10
#
# 2025-04-16 14:56:07,947 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:07,947 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9598 4413.4916 1.63980713289-03 1.4041228924-03  0.034607074817  0.034253724865     28      4   10
#
# 2025-04-16 14:56:07,948 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:08,048 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9599 4413.4958 1.63267765145-03 1.3985193024-03  0.034187485670  0.033812083228     28      4   10
#
# 2025-04-16 14:56:08,049 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        created new netcdf file ROMS_MARBL_rst.20120131120000.0.nc
#
# 2025-04-16 14:56:08,049 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        ocean_vars :: wrote restart, tdays =   4413.4958  step =   9599 rec =   1/  55
#
# 2025-04-16 14:56:08,049 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  doing BGC with MARBL
#
# 2025-04-16 14:56:08,050 | INFO | cstar.execution.local_process.LocalProcess::updates:168:    9600 4413.5000 1.62541176794-03 1.3928321708-03  0.033618077109  0.033068760594     28      4   10
#
# 2025-04-16 14:56:08,050 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        ocean_vars :: wrote history, tdays =   4413.5000  step =   9600 rec = 113
#
# 2025-04-16 14:56:08,050 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        ocean_vars :: wrote restart, tdays =   4413.5000  step =   9600 rec =   2/  56
#
# 2025-04-16 14:56:08,050 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  PO4
#
# 2025-04-16 14:56:08,051 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  NO3
#
# 2025-04-16 14:56:08,051 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  SiO3
#
# 2025-04-16 14:56:08,051 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  NH4
#
# 2025-04-16 14:56:08,051 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  Fe
#
# 2025-04-16 14:56:08,052 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  Lig
#
# 2025-04-16 14:56:08,052 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  O2
#
# 2025-04-16 14:56:08,052 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DIC
#
# 2025-04-16 14:56:08,052 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DIC_ALT_CO2
#
# 2025-04-16 14:56:08,053 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  ALK
#
# 2025-04-16 14:56:08,053 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  ALK_ALT_CO2
#
# 2025-04-16 14:56:08,053 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DOC
#
# 2025-04-16 14:56:08,054 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DON
#
# 2025-04-16 14:56:08,054 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DOP
#
# 2025-04-16 14:56:08,054 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DOPr
#
# 2025-04-16 14:56:08,054 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DONr
#
# 2025-04-16 14:56:08,055 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  DOCr
#
# 2025-04-16 14:56:08,055 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  zooC
#
# 2025-04-16 14:56:08,055 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  spChl
#
# 2025-04-16 14:56:08,056 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  spC
#
# 2025-04-16 14:56:08,056 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  spP
#
# 2025-04-16 14:56:08,056 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  spFe
#
# 2025-04-16 14:56:08,057 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  spCaCO3
#
# 2025-04-16 14:56:08,057 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatChl
#
# 2025-04-16 14:56:08,057 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatC
#
# 2025-04-16 14:56:08,057 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatP
#
# 2025-04-16 14:56:08,058 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatFe
#
# 2025-04-16 14:56:08,058 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diatSi
#
# 2025-04-16 14:56:08,058 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazChl
#
# 2025-04-16 14:56:08,058 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazC
#
# 2025-04-16 14:56:08,059 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazP
#
# 2025-04-16 14:56:08,059 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        wrt_bgc_tracers :: history , trc =  diazFe
#
# 2025-04-16 14:56:08,060 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        bgc :: wrote history, tdays =   4413.5000  step =   9599 rec = 113
#
# 2025-04-16 14:56:08,162 | INFO | cstar.execution.local_process.LocalProcess::updates:168:        bgc diag :: wrote history, tdays =   4413.5000  step =   9600 rec = 113
#
# 2025-04-16 14:56:08,163 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  Process    0  thread  0  cpu time =      107.66 sec
#
# 2025-04-16 14:56:08,170 | INFO | cstar.execution.local_process.LocalProcess::updates:168:
#
# 2025-04-16 14:56:08,173 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  MAIN: DONE - Records written:
#
# 2025-04-16 14:56:08,174 | INFO | cstar.execution.local_process.LocalProcess::updates:168:
#
# 2025-04-16 14:56:08,175 | INFO | cstar.execution.local_process.LocalProcess::updates:168:  MPI_run_time =   112.69302199999993
#
# 2025-04-16 14:56:08,175 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,178 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,179 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,179 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,180 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,187 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,190 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,190 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#
# 2025-04-16 14:56:08,191 | INFO | cstar.execution.local_process.LocalProcess::updates:168: Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
# completed

# %%
restarted_simulation.post_run()
# Out:
# Joining netCDF files ROMS_MARBL_rst.20120130120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120127120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_bgc_dia.20120103120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120120120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120113120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_bgc.20120103120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120114120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120126120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120108120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120104120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120119120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120118120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120105120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120117120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120124120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120106120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120128120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120107120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120112120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120110120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_his.20120103120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120121120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120115120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120116120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120123120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120122120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120125120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120129120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120131120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120109120000.*.nc...
# Command completed successfully.
# Joining netCDF files ROMS_MARBL_rst.20120111120000.*.nc...
# Command completed successfully.

# %% [markdown]
# ## 4. Some basic analysis of the output
#
# [(return to top)](#Contents)
#
# Now we've finished running the model, we have a month of output to take a look at.
#
# C-Star doesn't currently support plots of model data, so we will have to manually produce plots from the model files. Don't worry too much about understanding the model's naming conventions in this code cell (C-Star will usually take care of these things for you) - this is just a visual demonstration!

# %%
# %matplotlib inline

# %%
import numpy as np
import xarray as xr
import cartopy.crs as ccrs
import datetime as dt
import cartopy.feature as cfeature

output_path = restarted_simulation.directory

# bgc_ds contains 6-hourly data, with the date in the filename reflecting the first time entry
bgc_ds = xr.open_dataset(output_path / "output/ROMS_MARBL_bgc.20120103120000.nc")
grd_ds = xr.open_dataset(output_path / "ROMS/input_datasets/roms_grd.nc")
lon, lat = grd_ds.lon_rho, grd_ds.lat_rho
output_time = [
    dt.datetime(2000, 1, 1) + dt.timedelta(seconds=t) for t in bgc_ds.ocean_time.values
]

var = "DOC"
i_idx = 10
j_idx = 15
k_idx = 19
t_idx = [0, -1]

plot_data = bgc_ds[var].where(grd_ds.mask_rho).isel(s_rho=k_idx)

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


fig = plt.figure()
cmap = plt.get_cmap("Spectral_r")
cmap.set_bad("grey")

gs = GridSpec(3, 2, figure=fig, hspace=0.5)

# time series
ax1 = fig.add_subplot(gs[0, :])

ax1.plot(output_time, plot_data[:, j_idx, i_idx])
ax1.set_xlim(output_time[0], output_time[-1])
ax1.set_xlabel("time")
ax1.plot(output_time[t_idx[0]], plot_data[t_idx[0], j_idx, i_idx], "kx")
ax1.plot(output_time[t_idx[-1]], plot_data[t_idx[-1], j_idx, i_idx], "kx")


# Maps
ax2 = fig.add_subplot(gs[1:, 0], projection=ccrs.PlateCarree())
ax3 = fig.add_subplot(gs[1:, 1], projection=ccrs.PlateCarree())

VMIN = np.min(plot_data.values[plot_data.values > 0])
VMAX = np.max(plot_data.values[plot_data.values > 0])

p2 = ax2.pcolormesh(
    lon, lat, plot_data.isel(time=0).values, vmin=VMIN, vmax=VMAX, cmap=cmap
)
p3 = ax3.pcolormesh(
    lon, lat, plot_data.isel(time=-1).values, vmin=VMIN, vmax=VMAX, cmap=cmap
)
[a.set_xticks([]) for a in [ax2, ax3]]
[a.set_yticks([]) for a in [ax2, ax3]]

ax2.set_title("")
ax2.plot(lon[j_idx, i_idx].values - 360, lat[j_idx, i_idx].values, "kx")
ax3.plot(lon[j_idx, i_idx].values - 360, lat[j_idx, i_idx].values, "kx")

[a.add_feature(cfeature.COASTLINE, linewidth=1) for a in [ax3, ax2]]
fig.colorbar(p2, ax=ax2)
fig.colorbar(p3, ax=ax3)

fig.suptitle(f"Surface {bgc_ds[var].long_name}, ({bgc_ds[var].units})")
fig.set_size_inches(12, 6)
grd_ds.close()

# %% [markdown]
# ## Clean up test outputs
#
# Execute the following cell to clean up all files created during the tutorial

# %%
if 0:
    # clean up outputs when done
    import shutil

    shutil.rmtree("../../examples/outputs", ignore_errors=True)
